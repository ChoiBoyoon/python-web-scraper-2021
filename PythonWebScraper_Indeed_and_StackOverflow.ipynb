# %%
import requests #we can also use "urllib" but requests is more powerful

indeed_result = requests.get('https://www.indeed.com/jobs?q=python&limit=50')
print(indeed_result) #check if requests.get() works fine. <Response [200]> means "OK"
print(indeed_result.text[:100]) #print html (for test)
# Out:
# <Response [200]>
# <!DOCTYPE html>
# <html lang="en" dir="ltr">
# <head>
# <meta http-equiv="content-type" content="text/html

# %% [markdown]
# ### 1. Extract number of pages
# we need max page number in order to get all jobs on the site

# %%
from bs4 import BeautifulSoup
indeed_soup = BeautifulSoup(indeed_result.text, 'html.parser') #soup is data extractor

#from here, code should be changed if html of indeed.com is changed
pagination = indeed_soup.find("div", {"class":"pagination"})
pages = pagination.find_all('a') #find all anchors
spans = []
for page in pages[:-1]:
    spans.append(int(page.find('span').string))
max_page = max(spans)
print("max page: ",max_page)
# Out:
# max page:  5

# %% [markdown]
# **For reusibility, we'll write function that returns <u>max page number</u>**

# %%
LIMIT = 50
URL = f'https://www.indeed.com/jobs?q=python&limit={LIMIT}'

def get_last_page(): #return max page number
    result = requests.get(URL)
    soup = BeautifulSoup(result.text, 'html.parser') #soup is data extractor
    pagination = soup.find("div",{"class":"pagination"})
    pages = pagination.find_all('a')
    spans=[] #list containing page numbers
    for page in pages[:-1]:
        spans.append(int(page.find('span').string))
    max_page = max(spans)
    return max_page

# %% [markdown]
# ### 2. Extract job title, company name, location, and link

# %%
def extract_job(html):
    title = html.find("span", title=True).string
    company = html.find("span",{"class":"companyName"}).string
    location = html.select_one("pre>div").text
    job_id=html['data-jk']
    return {
        'title':title, 
        'company':company, 
        'location':location, 
        'link':f"https://www.indeed.com/viewjob?jk={job_id}"}


def extract_jobs(last_page):
    jobs = []
    for page in range(last_page):
        print(f"Scrapping Indeed: Page {page}...") #to check if it works fine
        result = requests.get(f"{URL}&start={page*LIMIT}")
        soup = BeautifulSoup(result.text, 'html.parser')
        results = soup.find_all("a",{"class":"tapItem"})
        for result in results:
            job = extract_job(result)
            jobs.append(job)
    return jobs
            
#test if functions above work well
def get_indeed_jobs():
    last_page = get_last_page()
    jobs = extract_jobs(last_page)
    return jobs

indeed_jobs = get_indeed_jobs()
print(indeed_jobs)
# Out:
# Scrapping Indeed: Page 0...
# Scrapping Indeed: Page 1...
# Scrapping Indeed: Page 2...
# Scrapping Indeed: Page 3...
# Scrapping Indeed: Page 4...
# [{'title': 'Python Software Engineering Teaching Assistant (Part-Time)', 'company': 'Hackbright Academy', 'location': '+2 locationsRemote', 'link': 'https://www.indeed.com/viewjob?jk=cc10e115d1ed386e'}, {'title': 'DBA Apprentice', 'company': 'WebMD', 'location': 'Newark, NJ 07102 (Central Business District area)', 'link': 'https://www.indeed.com/viewjob?jk=a7727fb4996b872c'}, {'title': 'Data Analyst (Python)', 'company': 'Qcentrio', 'location': '+1 locationRemote', 'link': 'https://www.indeed.com/viewjob?jk=d1218a12442b5c05'}, {'title': 'Software Engineer Python (Entry Level) - Remote', 'company': 'XR Trading LLC', 'location': 'Chicago, IL•Remote', 'link': 'https://www.indeed.com/viewjob?jk=9be66eb9484eee6f'}, {'title': 'Junior Python Developer', 'company': 'GTS', 'location': 'New York, NY 10022 (Midtown area)', 'link': 'https://www.indeed.com/viewjob?jk=71acc67a281f6038'}, {'title': 'Data Fellow - Remote - US', 'company': 'McClatchy', 'location': '+1 locationRemote', 'link': 'https://www.indeed.com/viewjob?jk=5780b7b923b7dbf1'}, {'title': 'Python and/or C++ Software Engineer', 'company': 'JPMorgan Chase Bank, N.A.', 'location': 'New York, NY+7 locations•Remote', 'link': 'https://www.indeed.com/viewjob?jk=357014a32fe97eeb'}, {'title': 'Python Developer', 'company': 'Synechron', 'location': 'Raleigh, NC+4 locations', 'link': 'https://www.indeed.com/viewjob?jk=264dd75c4173fbb7'}, {'title': 'Entry Level Cloud Consultant', 'company': 'IBM', 'location': 'Research Triangle Park, NC 27709+2 locations', 'link': 'https://www.indeed.com/viewjob?jk=b1a1fe0885e70918'}, {'title': 'CS152 Introduction to Python Programming', 'company': 'Park University Adjuncts', 'location': 'Ogden, UT+3 locations', 'link': 'https://www.indeed.com/viewjob?jk=295982114ccb7a52'}, {'title': 'Game Designer', 'company': 'Microsoft', 'location': 'Redmond, WA 98052 (Overlake area)', 'link': 'https://www.indeed.com/viewjob?jk=aaed53f15fec23d2'}, {'title': 'Python Developer', 'company': 'Nexient', 'location': 'Ann Arbor, MI 48108+1 location•Remote', 'link': 'https://www.indeed.com/viewjob?jk=37b2d4933fb25f5f'}, {'title': 'UX Engineer, Front End, Early Career', 'company': 'Google', 'location': 'San Francisco, CA+2 locations', 'link': 'https://www.indeed.com/viewjob?jk=bce1cc9db3680333'}, {'title': 'Python Engineer', 'company': 'Outside Online', 'location': 'Boulder, CO', 'link': 'https://www.indeed.com/viewjob?jk=896f0683f822304e'}, {'title': 'Threat Analyst - Entry to Expert Level', 'company': 'National Security Agency', 'location': 'Fort Meade, MD', 'link': 'https://www.indeed.com/viewjob?jk=ad4ce139128dcc4e'}, {'title': 'NERA Labor and Employment Researcher (2021 or earlier grads)', 'company': 'Oliver Wyman Group', 'location': 'Los Angeles, CA 90017 (Downtown area)', 'link': 'https://www.indeed.com/viewjob?jk=7ec76eb67e23ace1'}, {'title': 'Python Developer', 'company': 'Fults & Associates', 'location': 'Grapevine, TX', 'link': 'https://www.indeed.com/viewjob?jk=724d43dd753723a7'}, {'title': 'Python Curriculum Developer', 'company': 'The Flatiron School', 'location': 'New York State•Remote', 'link': 'https://www.indeed.com/viewjob?jk=7fa4d865ba4d418a'}, {'title': 'Associate Python Developer', 'company': 'JPMorgan Chase Bank, N.A.', 'location': 'Newark, DE 19713+32 locations', 'link': 'https://www.indeed.com/viewjob?jk=85f0b021348aeafc'}, {'title': 'Desarrollador Backend Python', 'company': 'Seeconds', 'location': 'Remote', 'link': 'https://www.indeed.com/viewjob?jk=d0eb1294325cb3f1'}, {'title': 'Research Assistant', 'company': 'States United Democracy Center', 'location': 'Remote', 'link': 'https://www.indeed.com/viewjob?jk=b166f8d88c2bcfa9'}, {'title': '3D Character Modeler- Marvel Studios Animation', 'company': 'Marvel Studios', 'location': 'Burbank, CA', 'link': 'https://www.indeed.com/viewjob?jk=316134078595163d'}, {'title': 'Rotational Analyst', 'company': 'Propel', 'location': 'New York State•Remote', 'link': 'https://www.indeed.com/viewjob?jk=7d588fddba5a1422 ...

# %% [markdown]
# ### StackOverflow

# %%
import requests
from bs4 import BeautifulSoup

URL = f"https://stackoverflow.com/jobs?q=python&sort=i"

#step 1: get the page
#step 2: make the request
#step 3: extract jobs

def get_last_page():
    result = requests.get(URL)
    soup = BeautifulSoup(result.text, 'html.parser')
    pages = soup.find("div",{"class":"s-pagination"}).find_all("a")
    last_page=pages[-2].get_text(strip=True)
    return int(last_page)

def extract_job(html): #singular. one by one
    title = html.find("h2",{"class":"mb4"}).find("a")["title"]
    company, location = html.find("h3",{"class":"fc-black-700"}).find_all("span", recursive=False) #resursive=0 means "don't go too deep. just get first two level"
    company = company.get_text(strip=True)
    location = location.get_text(strip=True)
    job_id = html['data-jobid']
    return {
        'title':title, 
        'company':company, 
        'location':location, 
        'link':f"https://stackoverflow.com/jobs/{job_id}"
    }

def extract_jobs(last_page):
    jobs=[]
    for page in range(last_page):
        print(f"Scrapping SO: Page {page}...") #for my mental health
        result = requests.get(f"{URL}&pg={page+1}")
        soup = BeautifulSoup(result.text, 'html.parser')
        results = soup.find_all("div",{"class":"-job"}) #"class":"listResults" ?
        for result in results:
            job = extract_job(result)
            jobs.append(job)
    return jobs
    
    
def get_so_jobs(): #get_jobs()
    last_page = get_last_page() #number of page can differ depending on 'user-agent'(info of user's OS&browser)
                                #how to get 'user-agent': https://www.whatismybrowser.com/detect/what-is-my-user-agent
    jobs = extract_jobs(last_page)
    return jobs

so_jobs = get_so_jobs()
print(so_jobs)
# Out:
# Scrapping SO: Page 0...
# Scrapping SO: Page 1...
# Scrapping SO: Page 2...
# Scrapping SO: Page 3...
# Scrapping SO: Page 4...
# Scrapping SO: Page 5...
# Scrapping SO: Page 6...
# Scrapping SO: Page 7...
# Scrapping SO: Page 8...
# Scrapping SO: Page 9...
# Scrapping SO: Page 10...
# Scrapping SO: Page 11...
# Scrapping SO: Page 12...
# Scrapping SO: Page 13...
# Scrapping SO: Page 14...
# Scrapping SO: Page 15...
# Scrapping SO: Page 16...
# Scrapping SO: Page 17...
# Scrapping SO: Page 18...
# Scrapping SO: Page 19...
# Scrapping SO: Page 20...
# Scrapping SO: Page 21...
# Scrapping SO: Page 22...
# Scrapping SO: Page 23...
# Scrapping SO: Page 24...
# Scrapping SO: Page 25...
# Scrapping SO: Page 26...
# Scrapping SO: Page 27...
# Scrapping SO: Page 28...
# Scrapping SO: Page 29...
# Scrapping SO: Page 30...
# Scrapping SO: Page 31...
# Scrapping SO: Page 32...
# Scrapping SO: Page 33...
# Scrapping SO: Page 34...
# Scrapping SO: Page 35...
# Scrapping SO: Page 36...
# Scrapping SO: Page 37...
# Scrapping SO: Page 38...
# Scrapping SO: Page 39...
# Scrapping SO: Page 40...
# Scrapping SO: Page 41...
# Scrapping SO: Page 42...
# Scrapping SO: Page 43...
# Scrapping SO: Page 44...
# Scrapping SO: Page 45...
# Scrapping SO: Page 46...
# Scrapping SO: Page 47...
# Scrapping SO: Page 48...
# Scrapping SO: Page 49...
# Scrapping SO: Page 50...
# Scrapping SO: Page 51...
# Scrapping SO: Page 52...
# Scrapping SO: Page 53...
# Scrapping SO: Page 54...
# Scrapping SO: Page 55...
# Scrapping SO: Page 56...
# Scrapping SO: Page 57...
# Scrapping SO: Page 58...
# Scrapping SO: Page 59...
# Scrapping SO: Page 60...
# Scrapping SO: Page 61...
# Scrapping SO: Page 62...
# Scrapping SO: Page 63...
# Scrapping SO: Page 64...
# Scrapping SO: Page 65...
# Scrapping SO: Page 66...
# Scrapping SO: Page 67...
# Scrapping SO: Page 68...
# Scrapping SO: Page 69...
# Scrapping SO: Page 70...
# Scrapping SO: Page 71...
# Scrapping SO: Page 72...
# Scrapping SO: Page 73...
# Scrapping SO: Page 74...
# [{'title': 'Engineering Manager', 'company': 'Tessian', 'location': 'London, UK', 'link': 'https://stackoverflow.com/jobs/558773'}, {'title': 'Senior Data Engineer (US Only)', 'company': 'Pie Insurance Holdings, Inc.', 'location': 'No office location', 'link': 'https://stackoverflow.com/jobs/545526'}, {'title': 'Data Engineer (US Only)', 'company': 'Pie Insurance Holdings, Inc.', 'location': 'No office location', 'link': 'https://stackoverflow.com/jobs/545525'}, {'title': 'Remote Software Engineer (Node.js) - Electriphi - EV Fleet & Energy Management', 'company': 'ElectriphiviaSource Coders', 'location': 'No office location', 'link': 'https://stackoverflow.com/jobs/559940'}, {'title': 'Senior Backend Engineer', 'company': 'Tessian', 'location': 'London, UK', 'link': 'https://stackoverflow.com/jobs/547940'}, {'title': 'Big Data / ETL Data Engineer (m/w/d)', 'company': 'Generali AG', 'location': 'Aachen, Deutschland', 'link': 'https://stackoverflow.com/jobs/559930'}, {'title': 'Data Science Engineer / Architect (m/w/d)', 'company': 'Generali AG', 'location': 'Aachen, Deutschland', 'link': 'https://stackoverflow.com/jobs/559928'}, {'title': 'Cloud Engineer (Azure, Google Cloud Platform, AWS)', 'company': 'ti&m AG', 'location': 'Bern, Schweiz', 'link': 'https://stackoverflow.com/jobs/522337'}, {'title': 'Cloud Data Architect mit Flair für AI', 'company': 'ti&m AG', 'location': 'Bern, Schweiz', 'link': 'https://stackoverflow.com/jobs/522336'}, {'title': 'Data Engineer', 'company': 'Huxley Banking & Financial ServicesviaHuxley (US)', 'location': 'Chicago, IL', 'link': 'https://stackoverflow.com/jobs/525601'}, {'title': 'Datenvisualisierung und Exploration für Erdbeobachtung/Autonomes Fahren/Energie', 'company': 'Deutsches Zentrum für Luft- und Raumfahrt e.V.', 'location': 'Jena, Deutschland', 'link': 'https://stackoverflow.com/jobs/555972'}, {'title': 'Senior Data Engineer (Data Warehouse)', 'company': 'NFQ Technologies', 'location': 'Vilnius, Lithuania', 'link': 'https://stackoverflow.com/jobs/555971'}, {'title': 'Cloud Engineer (Azure, Google Cloud Platform, AWS)', 'company': 'ti&m AG', 'location': 'Zürich, Schweiz', 'link': 'https://stackoverflow.com/jobs/522303'}, {'title': 'Cloud Data Engineer (m/w/d)', 'company': 'Generali AG', 'location': 'Aachen, Deutschland', 'link': 'https://stackoverflow.com/jobs/559926'}, {'title': 'Software developer for test automation (f/m/x)', 'company': 'OMICRON electronics GmbH', 'location': 'Klaus, Austria', 'link': 'https://stackoverflow.com/jobs/441369'}, {'title': 'Experienced Data Engineer', 'company': 'Accenture Romania', 'location': 'Bucharest, Romania', 'link': 'https://stackoverflow.com/jobs/525561'}, {'title': 'Full Stack Developer (Python / React)', 'company': 'Elorus', 'location': 'Athens, Greece', 'link': 'https://stackoverflow.com/jobs/551867'}, {'title': '(Senior) Systems Engineer im DevOps-Umfeld (m/w/d) in München', 'company': 'jambit GmbH', 'location': 'München, Deutschland', 'link': 'https://stackoverflow.com/jobs/483475'}, {'title': '(Senior) DevOps Engineer (m/w/d) in Leipzig', 'company': 'jambit GmbH', 'location': 'Leipzig, Deutschland', 'link': 'https://stackoverflow.com/jobs/455001'}, {'title': 'DevOps / Site Reliability Engineer (APAC timezone / remote)', 'company': 'Platform.sh', 'location': 'No office location', 'link': 'https://stackoverflow.com/jobs/559924'}, {'title': 'Data Scientist who loves to work on the Green Energy Transformation', 'company': 'HYDROGRID GmbH', 'location': 'Vienna, Austria', 'link': 'https://stackoverflow.com/jobs/559923'}, {'title': 'Site Reliability Engineer  (f/m) 80- 100%', 'company': 'TX Group', 'location': 'Zürich, Switzerland', 'link': 'https://stackoverflow.com/jobs/559918'}, {'title': 'Engineering Experience, Senior Software Engineer (Remote)', 'company': 'Hotjar', 'location': 'No office location', 'link': 'https://stackoverflow.com/jobs/528857'}, {'title': 'Senior Data Engineer (Remote)', 'company': 'Hotjar', 'location': 'No office locat ...

# %% [markdown]
# ### Get lists of jobs from two sites(indeed&stackoverflow) and save as CSV file

# %%
jobs = indeed_jobs + so_jobs

# %%
#version 1: classical method with file object
import csv

def save_to_file(jobs):
    file = open("jobs.csv", mode="w") #open a file
    writer = csv.writer(file) #make a writer object
    writer.writerow(["title", "company", "location", "link"])
    for job in jobs:
        writer.writerow(list(job.values())) #without list, data type is 'dict_values'
    return

save_to_file(jobs)

# %%
#version 2: with open() handler (safer way to write a file, recommended)
import csv

def save_to_file(jobs):
    with open("jobs.csv", 'w', newline='') as csv_file:
        columns = ["title", "company", "location", "link"]
        writer = csv.DictWriter(csv_file, fieldnames = columns)
        writer.writeheader()
        for job in jobs:
            writer.writerow(job)
            
save_to_file(jobs)

# %%
import requests #we can also use "urllib" but "requests" is more powerful

indeed_result = requests.get('https://www.indeed.com/jobs?q=python&limit=50')
print(indeed_result) #check if requests.get() works fine. <Response [200]> means "OK"
print(indeed_result.text[:100]) #print html (for test)
# Out:
# <Response [200]>
# <!DOCTYPE html>
# <html lang="en" dir="ltr">
# <head>
# <meta http-equiv="content-type" content="text/html

# %% [markdown]
# ### 1. Extract number of pages
# we need max page number in order to get all jobs on the site

# %%
from bs4 import BeautifulSoup
indeed_soup = BeautifulSoup(indeed_result.text, 'html.parser') #soup is data extractor

#from here, code should be changed if html of indeed.com is modified
pagination = indeed_soup.find("div", {"class":"pagination"})
print(pagination)
pages = pagination.find_all('a') #find all anchors
spans = []
for page in pages[:-1]:
    print(page.find('span'))
    spans.append(int(page.find('span').string))
max_page = max(spans)
print("max page: ",max_page)
# Out:
# <div class="pagination" onmousedown="pclk(event);">
# <ul class="pagination-list">
# <li><b aria-current="true" aria-label="1" tabindex="0">1</b></li><li><a aria-label="2" data-pp="gQAyAAAAAAAAAAAAAAABvK5TOQBeAQMBDiYGHgYGLKMkGOV31hS4dUbB8rTosXdt9HP3IRbpkCcD5vIGu5tLASBV42tKkgpjWzzKdEmo_sShi-EW8rLbUTVh3_NHyLUL64wqx-LiibajvdWYhkkv_Wa59gAA" href="/jobs?q=python&amp;limit=50&amp;start=50" onmousedown="addPPUrlParam &amp;&amp; addPPUrlParam(this);" rel="nofollow"><span class="pn">2</span></a></li><li><a aria-label="3" data-pp="gQBkAAAAAAAAAAAAAAABvK5TOQCdAQIBHUwGAuytlawyZ3fk1rURh7dm2SmyD-GclUrxmWGwyWwf_hCsKP6BYchUEpZBRrvP--1NR5jPnHtGvrTa7yUAygd0WA_D_zp6l3juY1KTczVw2tWGihJMehl3xwD_1-HA4uYl95t_yIKxumsgSrXTXCM4RXeyHTveAWj-jtdORs9aZdnvF1NxGKLOTgU_WI1W1ekvEqF3UzcyYwAA" href="/jobs?q=python&amp;limit=50&amp;start=100" onmousedown="addPPUrlParam &amp;&amp; addPPUrlParam(this);" rel="nofollow"><span class="pn">3</span></a></li><li><a aria-label="4" data-pp="gQCWAAAAAAAAAAAAAAABvK5TOQDKAQQBIEwGHgZQBh4s1AmFhrqpCETl7ncNFA1cb79k6E0Lq5BAhXlR62Ty-y7MDfdNLYqRk6CDXoOre89sVoK78RNZWywYnyBOGcJey_KsM6vcncyQuG_K2xGNM8aNBWv5EyxcsBRHxHYUwrRSNwp7hUHaUNyDkc6nTJy2fLcSWqobZvyARugsiCtJyw4HsW_uBtvm7KG49Rf4I5A76FEybQym4nWOCzC6XaRZO1iaWBhu7_4E1APMZMF21keFWGHc1OK1DprihAErzgAA" href="/jobs?q=python&amp;limit=50&amp;start=150" onmousedown="addPPUrlParam &amp;&amp; addPPUrlParam(this);" rel="nofollow"><span class="pn">4</span></a></li><li><a aria-label="5" data-pp="gQDIAAAAAAAAAAAAAAABvK5TOQDtAQUBLGoKMgYeCBIJBRBw1x0qf8XJ5_eHw0Hkggu4QByxuQqoDOgHtJplg6Fy4d29aoBL--9Pl5V8PI2HwxsKjhNYjWdT-mCtS09JRQ1PMUrmRcquu9jx0ClUVullvwM4b9OQHIA4-ApP2WhHsTg-8w7cYo-U_c6C6A-xv0gAPdxIw9s27fdR2AYgsK_y2JFfDEhY-qlGeN-mmHoN6RgomTUyXo8gagr6TiTJB7MsgQ0mGzSy0KWLF7OQDOZ1NZ-miM9uz36OyTLWBcZT4jg8q2TWKp4Cgap3mFzxSrzvmUrutEOcSTb4PJXt_2gzAAA" href="/jobs?q=python&amp;limit=50&amp;start=200" onmousedown="addPPUrlParam &amp;&amp; addPPUrlParam(this);" rel="nofollow"><span class="pn">5</span></a></li><li><a aria-label="Next" data-pp="gQAyAAAAAAAAAAAAAAABvK5TOQBeAQMBDiYGHgYGLKMkGOV31hS4dUbB8rTosXdt9HP3IRbpkCcD5vIGu5tLASBV42tKkgpjWzzKdEmo_sShi-EW8rLbUTVh3_NHyLUL64wqx-LiibajvdWYhkkv_Wa59gAA" href="/jobs?q=python&amp;limit=50&amp;start=50" onmousedown="addPPUrlParam &amp;&amp; addPPUrlParam(this);" rel="nofollow"><span class="pn"><span class="np"><svg fill="none" height="24" width="24"><path d="M10 6L8.59 7.41 13.17 12l-4.58 4.59L10 18l6-6-6-6z" fill="#2D2D2D"></path></svg></span></span></a></li></ul>
# </div>
# <span class="pn">2</span>
# <span class="pn">3</span>
# <span class="pn">4</span>
# <span class="pn">5</span>
# max page:  5

# %% [markdown]
# **For reusibility, we'll write function that returns <u>max page number</u>**

# %%
LIMIT = 50
URL = f'https://www.indeed.com/jobs?q=python&limit={LIMIT}'

def extract_indeed_page(): #return max page number
    result = requests.get(URL)
    soup = BeautifulSoup(result.text, 'html.parser') #soup is data extractor
    pagination = soup.find("div",{"class":"pagination"})
    pages = pagination.find_all('a')
    spans=[] #list containing page numbers
    for page in pages[:-1]:
        spans.append(int(page.find('span').string))
    max_page = max(spans)
    return max_page

# %% [markdown]
# ### 2. Extract job title, company name, location, and link

# %%
def extract_job(html):
    title = html.find("span", title=True).string
    company = html.find("span",{"class":"companyName"}).string
    location = html.select_one("pre>div").text
    job_id=html['data-jk']
    return {'title':title, 'company':company, 'location':location, 'link':f"https://www.indeed.com/viewjob?jk={job_id}"}


def extract_indeed_jobs(last_page):
    jobs = []
    for page in range(last_page):
        print(f"Scrapping page {page}")
        result = requests.get(f"{URL}&start={page*LIMIT}")
        soup = BeautifulSoup(result.text, 'html.parser')
        results = soup.find_all("a",{"class":"tapItem"})
        for result in results:
            job = extract_job(result)
            jobs.append(job)
    return jobs
            
#test code
last_indeed_page = extract_indeed_page()
extract_indeed_jobs(last_indeed_page)
# Out:
# Scrapping page 0
# Scrapping page 1
# Scrapping page 2
# Scrapping page 3
# Scrapping page 4
# [{'title': 'Python Engineer',
#   'company': 'Outside Online',
#   'location': 'Boulder, CO',
#   'link': 'https://www.indeed.com/viewjob?jk=896f0683f822304e'},
#  {'title': 'DBA Apprentice',
#   'company': 'WebMD',
#   'location': 'Newark, NJ 07102 (Central Business District area)',
#   'link': 'https://www.indeed.com/viewjob?jk=a7727fb4996b872c'},
#  {'title': 'Software Engineer (PHP/Python)',
#   'company': 'Catchpoint',
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=e06b448fecf5553d'},
#  {'title': 'Entry Level Business Analyst-Remote',
#   'company': 'Agama Solutions',
#   'location': '+2 locationsRemote',
#   'link': 'https://www.indeed.com/viewjob?jk=6f6a1c18da31655b'},
#  {'title': 'Python Software Engineering Teaching Assistant (Part-Time)',
#   'company': 'Hackbright Academy',
#   'location': '+2 locationsRemote',
#   'link': 'https://www.indeed.com/viewjob?jk=cc10e115d1ed386e'},
#  {'title': 'Game Designer',
#   'company': 'Microsoft',
#   'location': 'Redmond, WA 98052 (Overlake area)',
#   'link': 'https://www.indeed.com/viewjob?jk=aaed53f15fec23d2'},
#  {'title': 'Python Developer',
#   'company': 'Virtusa',
#   'location': 'Jersey City, NJ',
#   'link': 'https://www.indeed.com/viewjob?jk=75f73b57fd4372d3'},
#  {'title': '3D Character Modeler- Marvel Studios Animation',
#   'company': 'Marvel Studios',
#   'location': 'Burbank, CA',
#   'link': 'https://www.indeed.com/viewjob?jk=316134078595163d'},
#  {'title': 'Junior Python Developer',
#   'company': 'GTS',
#   'location': 'New York, NY 10022 (Midtown area)',
#   'link': 'https://www.indeed.com/viewjob?jk=71acc67a281f6038'},
#  {'title': 'University Grad Software Engineer (USA)',
#   'company': 'Pinterest',
#   'location': 'Seattle, WA 98101 (Denny Triangle area)+6 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=4b7d149a76d895ec'},
#  {'title': 'UX Engineer, Front End, Early Career',
#   'company': 'Google',
#   'location': 'San Francisco, CA+2 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=bce1cc9db3680333'},
#  {'title': 'Mission Design Engineer - Mission Design and Navigation',
#   'company': 'JPL/NASA',
#   'location': 'Pasadena, CA 91109',
#   'link': 'https://www.indeed.com/viewjob?jk=4d0e638c71140781'},
#  {'title': 'Python Developer-Reactjs',
#   'company': 'SmarTek21, LLC',
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=034026350a31dc8e'},
#  {'title': 'PhD Residency - Supply Chain - Agent-Based Modeling',
#   'company': 'Loon',
#   'location': 'Mountain View, CA',
#   'link': 'https://www.indeed.com/viewjob?jk=f877a6cd9b93bc8e'},
#  {'title': 'Software Engineer - Recent/Upcoming Graduates',
#   'company': 'Performance',
#   'location': 'Bothell, WA 98021+5 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=a89e488ec4bd9669'},
#  {'title': 'Online Programs Instructor (Coding)',
#   'company': 'YoungSkillz',
#   'location': 'United States',
#   'link': 'https://www.indeed.com/viewjob?jk=17a98ae692df0630'},
#  {'title': 'Software Developer, Python',
#   'company': 'Vertical Knowledge',
#   'location': 'Chagrin Falls, OH•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=621f947d91e7edd3'},
#  {'title': 'Full Stack Developer',
#   'company': 'OmStars',
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=28f4eba06a19dd23'},
#  {'title': 'Python Developer',
#   'company': 'Shuup Commerce Inc',
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=f9534ae0091f5310'},
#  {'title': 'Fully Remote WFM Data Scientist',
#   'company': 'CVS Health',
#   'location': '+10 locationsRemote',
#   'link': 'https://www.indeed.com/viewjob?jk=cb089760c4ec6d03'},
#  {'title': 'Content Creator',
#   'company': 'LeetCode',
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=e94af63cb41ad9b5'},
#  {'title': 'Applied Biomechanics Researcher',
#   'company': 'Apple',
#   'location': 'Cupertino, CA+2 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=ef8bfdf697ccd979'},
#  {'title': 'PYTHON DEVELOPER',
#   'company': 'Pythonwise',
#   'location': 'Seattle, WA',
#   'link': 'https://www.indeed.com/viewjob?jk=1a20a1c56fb7df73'},
#  {'title': 'People Analytics Partner',
#   'company': 'Netflix',
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=79c852a11001e519'},
#  {'title': 'Web Development Education Apprentice: Remote Instruction',
#   'company': 'The Last Mile (TLM)',
#   'location': '+1 locationRemote',
#   'link': 'https://www.indeed.com/viewjob?jk=c8573af2b813e492'},
#  {'title': 'Middle Python Developer',
#   'company': 'AgileEngine',
#   'location': 'Grow, TX',
#   'link': 'https://www.indeed.com/viewjob?jk=cd3fbcf2d291ea7d'},
#  {'title': 'Software Developer – Entry Level',
#   'company': 'Grant Street Group',
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=45b11d0ceeec3818'},
#  {'title': 'Python Web Developer',
#   'company': 'Adapt2 Solutions, Inc.',
#   'location': 'Houston, TX 77024 (Memorial area)',
#   'link': 'https://www.indeed.com/viewjob?jk=312bff4492bd6468'},
#  {'title': 'Backend Software Engineer-TikTok',
#   'company': 'TikTok',
#   'location': 'Seattle, WA+16 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=523fdbe809b6c2f2'},
#  {'title': 'Python Engineer (remote)',
#   'company': 'magnitude',
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=0579faf2b17d7b9d'},
#  {'title': 'DATA ANALYST',
#   'company': 'InspiHER Tech',
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=4842f3e5cde55a12'},
#  {'title': 'Post Doctoral Fellow',
#   'company': 'University of Houston',
#   'location': 'Houston, TX',
#   'link': 'https://www.indeed.com/viewjob?jk=0023e423abe7be8d'},
#  {'title': 'Greece',
#   'company': 'Scout Gaming Group',
#   'location': 'Back, TX',
#   'link': 'https://www.indeed.com/viewjob?jk=d32e26c5101e4206'},
#  {'title': 'Machine Learning Engineer',
#   'company': 'Double River Investments Limited',
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=bb1cf2320fd7fc69'},
#  {'title': 'Entry Level Data Scientist: 2022',
#   'company': 'IBM',
#   'location': 'Research Triangle Park, NC 27709+2 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=d9dc2b2ff8863e63'},
#  {'title': 'Modeling & Architecture Engineer - Energy Products',
#   'company': 'Tesla',
#   'location': 'Palo Alto, CA+1 location',
#   'link': 'https://www.indeed.com/viewjob?jk=7cb8ecf7664f57b2'},
#  {'title': 'Python Developer',
#   'company': 'Fults & Associates',
#   'location': 'Grapevine, TX',
#   'link': 'https://www.indeed.com/viewjob?jk=724d43dd753723a7'},
#  {'title': 'Junior Data Analyst',
#   'company': 'Amazon',
#   'location': 'Seattle, WA+6 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=57487afcd1441435'},
#  {'title': 'Python Developer',
#   'company': 'Swan Software Solutions',
#   'location': 'Carmel, IN',
#   'link': 'https://www.indeed.com/viewjob?jk=32eaa9e1e80e8c5d'},
#  {'title': 'Python Developer',
#   'company': 'Highbrow-Tech',
#   'location': 'Hartford, CT+1 location',
#   'link': 'https://www.indeed.com/viewjob?jk=bf411dc5f9c747cd'},
#  {'title': 'Level Designer',
#   'company': 'Activision',
#   'location': 'Carlsbad, CA',
#   'link': 'https://www.indeed.com/viewjob?jk=0b2ae0c35b2c8686'},
#  {'title': 'Software Engineer Python (Entry Level) - Remote',
#   'company': 'XR Trading LLC',
#   'location': 'Chicago, IL•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=9be66eb9484eee6f'},
#  {'title': 'JUNIOR PYTHON DEVELOPER',
#   'company': 'Solutions Resource',
#   'location': 'Bellevue, WA',
#   'link': 'https://www.indeed.com/viewjob?jk=ad2bbe549fe4881c'},
#  {'title': 'Python Developer',
#   'company': 'Snap IT Solutions',
#   'location': 'Houston, TX 77099 (Alief area)',
#   'link': 'https://www.indeed.com/viewjob?jk=0e10fe734c597c75'},
#  {'title': 'AI engineer',
#   'company': 'Sticker Mule',
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=ff5307e29c1967f0'},
#  {'title': 'Software Engineering New College Grad (pursuing Bachelor of...',
#   'company': 'Western Digital',
#   'location': 'San Jose, CA 95138 (Santa Teresa area)+2 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=ce0461e9832e165b'},
#  {'title': 'Python Engineer',
#   'company': 'Vanguard',
#   'location': 'Charlotte, NC',
#   'link': 'https://www.indeed.com/viewjob?jk=2c7aeb223f9a69a4'},
#  {'title': 'Python Developer',
#   'company': 'Nexient',
#   'location': 'Ann Arbor, MI 48108+1 location•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=37b2d4933fb25f5f'},
#  {'title': 'Quantitative Trader - Entry Level',
#   'company': 'Avatar Securities',
#   'location': 'Chicago, IL',
#   'link': 'https://www.indeed.com/viewjob?jk=d01efa8dad29efdc'},
#  {'title': 'Marketing Analyst, Ads Marketing Analytics',
#   'company': 'Google',
#   'location': 'New York, NY (Chelsea area)+3 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=3e14b12a80156d20'},
#  {'title': 'Software Engineer (PHP/Python)',
#   'company': 'Catchpoint',
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=e06b448fecf5553d'},
#  {'title': 'Undergrad New College Grad - Technology - Multiple Locations',
#   'company': 'Visa',
#   'location': 'Bellevue, WA+9 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=542962c95b01cf46'},
#  {'title': 'Research Data Analyst 2',
#   'company': 'UC San Diego',
#   'location': 'San Diego, CA',
#   'link': 'https://www.indeed.com/viewjob?jk=707278aa77818fe9'},
#  {'title': 'Python Engineer',
#   'company': 'Vanguard',
#   'location': 'Charlotte, NC',
#   'link': 'https://www.indeed.com/viewjob?jk=2c7aeb223f9a69a4'},
#  {'title': 'AWS Cloud Computing Specialist + Apprentice',
#   'company': 'New Apprenticeship',
#   'location': 'Richardson, TX 75082+1 location•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=7623480e12b06704'},
#  {'title': 'Entry Level Data Scientist: 2022',
#   'company': 'IBM',
#   'location': 'Research Triangle Park, NC 27709+2 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=d9dc2b2ff8863e63'},
#  {'title': 'Cell Engineer, Supercharger',
#   'company': 'Tesla',
#   'location': 'Palo Alto, CA+4 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=e3571e481ca430bd'},
#  {'title': 'Python Developer Anywhere',
#   'company': 'Santex Group',
#   'location': 'United States',
#   'link': 'https://www.indeed.com/viewjob?jk=040f2c487a3dd6d3'},
#  {'title': 'Python Backend Developer (Remote)',
#   'company': 'Parlance',
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=c2437828c44a5ef9'},
#  {'title': 'Python Developer',
#   'company': 'Convazant',
#   'location': 'Sunnyvale, CA',
#   'link': 'https://www.indeed.com/viewjob?jk=3bd86e0ab712b364'},
#  {'title': '2022 Business Analyst FTE',
#   'company': 'Amazon.com Services LLC',
#   'location': 'Seattle, WA+59 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=dfc8a3163469a524'},
#  {'title': 'Python Developer-1',
#   'company': 'TIAA',
#   'location': 'New York State',
#   'link': 'https://www.indeed.com/viewjob?jk=b736f44252e1d179'},
#  {'title': 'Python Web Developer',
#   'company': 'Adapt2 Solutions, Inc.',
#   'location': 'Houston, TX 77024 (Memorial area)',
#   'link': 'https://www.indeed.com/viewjob?jk=312bff4492bd6468'},
#  {'title': 'Junior Data Scientist',
#   'company': 'IHS Markit',
#   'location': 'Southfield, MI',
#   'link': 'https://www.indeed.com/viewjob?jk=6795295025da4d83'},
#  {'title': 'Jr. Developer [Python, SQL, Javascript]',
#   'company': 'Horizon Media, Inc.',
#   'location': 'New York, NY',
#   'link': 'https://www.indeed.com/viewjob?jk=763ce5d7d99a83be'},
#  {'title': 'Next Gen Stats Analyst',
#   'company': 'National Football League',
#   'location': 'Culver City, CA 90232',
#   'link': 'https://www.indeed.com/viewjob?jk=d3680957c17c91fc'},
#  {'title': 'Level Designer',
#   'company': 'Activision',
#   'location': 'Carlsbad, CA',
#   'link': 'https://www.indeed.com/viewjob?jk=0b2ae0c35b2c8686'},
#  {'title': 'Application Developer Apprentice - MR',
#   'company': 'IBM',
#   'location': 'Monroe, LA 71201+7 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=619c3ef43f483bcd'},
#  {'title': 'Backend Developer',
#   'company': "Boston Children's Hospital",
#   'location': 'Boston, MA',
#   'link': 'https://www.indeed.com/viewjob?jk=8e62706974971556'},
#  {'title': 'Software Engineer, Early Career',
#   'company': 'ViaSat',
#   'location': 'Carlsbad, CA+25 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=4b87183561e86206'},
#  {'title': 'PYTHON DEVELOPER',
#   'company': 'OC10',
#   'location': 'Charlotte, NC 28202 (Downtown Charlotte area)',
#   'link': 'https://www.indeed.com/viewjob?jk=f26b8209c93fdd28'},
#  {'title': 'Full-stack Developer',
#   'company': 'UC San Diego',
#   'location': 'San Diego, CA 92093 (Torrey Pines area)•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=0a365cead4f1ff64'},
#  {'title': 'Data Analyst (Remote)',
#   'company': 'pulseData',
#   'location': 'New York, NY•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=bdae6adbea0b40f1'},
#  {'title': 'Entry Level Business Analyst-Remote',
#   'company': 'Agama Solutions',
#   'location': '+2 locationsRemote',
#   'link': 'https://www.indeed.com/viewjob?jk=6f6a1c18da31655b'},
#  {'title': 'Entry Level - Data Analyst',
#   'company': 'General Motors',
#   'location': 'United States+3 locations•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=e5b2f877c37714da'},
#  {'title': 'Entry Level Application Developer',
#   'company': 'DataLab USA',
#   'location': 'Germantown, MD 20876',
#   'link': 'https://www.indeed.com/viewjob?jk=e9f7044abbb59a9c'},
#  {'title': 'Software Engineering- Python',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX+110 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=7db2038a597b7fcf'},
#  {'title': 'Research Engineer',
#   'company': 'Optiver',
#   'location': 'Austin, TX',
#   'link': 'https://www.indeed.com/viewjob?jk=adcd5b2860b6d49d'},
#  {'title': 'Data Scientist - Entry Level',
#   'company': 'Numerdox',
#   'location': 'Sacramento, CA•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=3dde0133818987f0'},
#  {'title': 'Analyst I/II, Data Science',
#   'company': 'Liberty Mutual Insurance',
#   'location': '+4 locationsRemote',
#   'link': 'https://www.indeed.com/viewjob?jk=99944852e6adfe64'},
#  {'title': 'Python Tester',
#   'company': 'Accenture',
#   'location': 'Redmond, WA',
#   'link': 'https://www.indeed.com/viewjob?jk=ee4976f2befef230'},
#  {'title': 'Data Scientist',
#   'company': 'J.Crew',
#   'location': 'New York, NY 10281 (Battery Park area)+1 location',
#   'link': 'https://www.indeed.com/viewjob?jk=00df9455af289616'},
#  {'title': 'SCHISM Modeler/ Oceanographer',
#   'company': 'Columbia River Inter-Tribal Fish Commission...',
#   'location': 'Portland, OR',
#   'link': 'https://www.indeed.com/viewjob?jk=4deccd564e80aa67'},
#  {'title': 'Jr. Developer',
#   'company': 'Deloitte',
#   'location': 'Foster City, CA+68 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=679c2375a34a2a91'},
#  {'title': 'Python Developer',
#   'company': 'Novogradac & Company',
#   'location': 'Austin, TX+5 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=451ec9cceaa4ec41'},
#  {'title': 'Quantitative role in the Model Review Group',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'New York, NY+3 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=1d3ee0c9f13b3e25'},
#  {'title': 'Customer Technical Support Representative - Part Time',
#   'company': 'Wiley',
#   'location': 'United States•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=aec3c774eefadb20'},
#  {'title': 'Intelligence Investigator, Violent Extremism and Criminal Or...',
#   'company': 'Google',
#   'location': 'New York, NY (Chelsea area)',
#   'link': 'https://www.indeed.com/viewjob?jk=a22b52542a7a7b90'},
#  {'title': 'Associate Data Analyst',
#   'company': 'Verint Systems Inc.',
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=c5b24a734dc35fd8'},
#  {'title': 'Python/ ETL Tester',
#   'company': 'Intone Networks',
#   'location': 'Austin, TX',
#   'link': 'https://www.indeed.com/viewjob?jk=085a7de8ddf9c330'},
#  {'title': 'Look of Picture TD (Avatar Studios)',
#   'company': 'Nickelodeon Animation',
#   'location': 'Burbank, CA 91502',
#   'link': 'https://www.indeed.com/viewjob?jk=499f72e5cbd7ab3b'},
#  {'title': 'Python Django Developer',
#   'company': 'Intone Networks',
#   'location': '+8 locationsRemote',
#   'link': 'https://www.indeed.com/viewjob?jk=8cfd8d4e033b2ce9'},
#  {'title': 'Front End Engineer',
#   'company': 'Outside Online',
#   'location': 'Boulder, CO',
#   'link': 'https://www.indeed.com/viewjob?jk=6dfabdf9cf09f7bf'},
#  {'title': 'Data Analyst',
#   'company': 'Disney Streaming',
#   'location': 'New York, NY+5 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=2805b60985e5e410'},
#  {'title': 'Jr Systems Development Engineer',
#   'company': 'Amazon.com Services LLC',
#   'location': 'San Luis Obispo, CA 93401',
#   'link': 'https://www.indeed.com/viewjob?jk=b9e06c23ff9cd7e3'},
#  {'title': 'CS152 Introduction to Python Programming',
#   'company': 'Park University Adjuncts',
#   'location': 'Ogden, UT+3 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=2d66bbf4faa5c0f1'},
#  {'title': 'Data Scientist',
#   'company': 'Disney Streaming',
#   'location': 'Santa Monica, CA',
#   'link': 'https://www.indeed.com/viewjob?jk=9d9480ef13d0c26c'},
#  {'title': 'DATA ANALYST',
#   'company': 'InspiHER Tech',
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=4842f3e5cde55a12'},
#  {'title': 'Software Developer – Entry Level',
#   'company': 'Grant Street Group',
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=45b11d0ceeec3818'},
#  {'title': 'Marketing Analyst, Ads Marketing Analytics',
#   'company': 'Google',
#   'location': 'New York, NY (Chelsea area)+3 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=3e14b12a80156d20'},
#  {'title': 'Python Developer',
#   'company': 'Melon, Inc.',
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=1784f338f04273e1'},
#  {'title': 'Quality Assurance Analyst',
#   'company': 'Health & Human Services Comm',
#   'location': 'Austin, TX 78701 (Downtown area)',
#   'link': 'https://www.indeed.com/viewjob?jk=936a746c3a20c95e'},
#  {'title': 'Web Development Education Apprentice: Remote Instruction',
#   'company': 'The Last Mile (TLM)',
#   'location': '+1 locationRemote',
#   'link': 'https://www.indeed.com/viewjob?jk=c8573af2b813e492'},
#  {'title': 'Software Engineer - Python',
#   'company': 'Backstage',
#   'location': 'New York, NY•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=2814f981b67e8b0b'},
#  {'title': 'Backend Software Engineer-TikTok',
#   'company': 'TikTok',
#   'location': 'Seattle, WA+16 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=523fdbe809b6c2f2'},
#  {'title': 'Software Engineer (Early Career)',
#   'company': 'Apple',
#   'location': 'Austin, TX+81 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=aaddb765eb8a7fee'},
#  {'title': 'QIS Structurer - NY',
#   'company': 'Morgan Stanley',
#   'location': 'New York, NY',
#   'link': 'https://www.indeed.com/viewjob?jk=85b816c46e02c704'},
#  {'title': 'Propulsion — Associate Engineer (Spring 2022)',
#   'company': 'Astranis',
#   'location': 'San Francisco, CA+1 location',
#   'link': 'https://www.indeed.com/viewjob?jk=b1060fd97370fbb6'},
#  {'title': 'Senior Python Developer',
#   'company': 'ShipHero',
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=1ef36fc836615b49'},
#  {'title': 'Python/SAS/Pyspark/modeling consultant (remote)',
#   'company': 'RiskSpan',
#   'location': 'United States•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=2997e343d7c1ae1b'},
#  {'title': 'Jr. Python Developer',
#   'company': 'Kibo Commerce',
#   'location': 'Dallas, TX 75201',
#   'link': 'https://www.indeed.com/viewjob?jk=5ccd82b0221de315'},
#  {'title': 'GIS Technician',
#   'company': 'Flo Analytics',
#   'location': 'Seattle, WA+1 location',
#   'link': 'https://www.indeed.com/viewjob?jk=b5e9951b5f0dfff4'},
#  {'title': 'HAF CCC Fellow - Willapa National Wildlife Refuge, Washingto...',
#   'company': 'Hispanic Access Foundation',
#   'location': 'Long Beach, WA+12 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=68e1652362f31e6e'},
#  {'title': '3D Modeler - Hard Surface - Permanent Remote',
#   'company': 'Webstaurant Store, Inc.',
#   'location': 'Lititz, PA 17543•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=f1d95ac60afce9fa'},
#  {'title': 'GIS Technician I',
#   'company': 'City of Palm Bay, FL',
#   'location': 'Palm Bay, FL',
#   'link': 'https://www.indeed.com/viewjob?jk=6b1df15169897002'},
#  {'title': 'Software Engineer I - Scientific Python Developer',
#   'company': 'University Corporation for Atmospheric Research',
#   'location': 'Boulder, CO',
#   'link': 'https://www.indeed.com/viewjob?jk=c3a123a24225011f'},
#  {'title': 'Production Support Developer (Python)',
#   'company': 'GTS',
#   'location': 'New York, NY 10022 (Midtown area)',
#   'link': 'https://www.indeed.com/viewjob?jk=571e99b938ae96cf'},
#  {'title': 'Data Visualization Engineer (Remote)',
#   'company': 'pulseData',
#   'location': 'New York, NY•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=3942093fd1bd16d3'},
#  {'title': 'Associate Data Scientist',
#   'company': 'Nike',
#   'location': 'Beaverton, OR+16 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=b671f77fb3e65fef'},
#  {'title': 'Graduate Quantitative Trader (2022 Start - Chicago)',
#   'company': 'Optiver',
#   'location': 'Chicago, IL',
#   'link': 'https://www.indeed.com/viewjob?jk=ab5fe64e39cb8c44'},
#  {'title': 'Software Developer I (JavaScript and Python)',
#   'company': 'Champaign County',
#   'location': 'Urbana, IL 61802',
#   'link': 'https://www.indeed.com/viewjob?jk=d908df9ee6b67aca'},
#  {'title': 'Analyst, Product Research',
#   'company': 'Liberty Mutual Insurance',
#   'location': '+2 locationsRemote',
#   'link': 'https://www.indeed.com/viewjob?jk=e68a9e40a6adf6bf'},
#  {'title': 'Professional Applications Developer',
#   'company': 'AT&T',
#   'location': 'Atlanta, GA+2 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=e07869bab63709df'},
#  {'title': 'Drone Operator, Prime Air',
#   'company': 'Amazon.com Services LLC',
#   'location': 'Oregon',
#   'link': 'https://www.indeed.com/viewjob?jk=b2ba1e603d5e5bc7'},
#  {'title': 'Junior Software Engineer',
#   'company': 'Alloy',
#   'location': 'New York, NY•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=813829bb6c109643'},
#  {'title': 'Financial Crimes Strategy Specialist',
#   'company': 'Alliance Data',
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=0de319a84a3e7d9c'},
#  {'title': 'Threat Hunter, Remote',
#   'company': 'PONDURANCE, LLC',
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=badd471d2061b121'},
#  {'title': 'Python Developer',
#   'company': 'DUNBAR CONSULTING',
#   'location': 'Annapolis, MD',
#   'link': 'https://www.indeed.com/viewjob?jk=51fc7b53c649dae6'},
#  {'title': 'Data Engineer- Remote',
#   'company': 'Guardian Life Insurance Company',
#   'location': 'New York, NY+2 locations•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=66fb9935ee9766eb'},
#  {'title': 'Kofax Platform Engineer (Remote)',
#   'company': 'KAR Global',
#   'location': 'Carmel, IN 46032•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=18fab0d2af495585'},
#  {'title': 'Software Engineer, Backend - Slack (Senior and Staff)',
#   'company': 'Slack',
#   'location': '+5 locationsRemote',
#   'link': 'https://www.indeed.com/viewjob?jk=4854ee830704f0c9'},
#  {'title': 'Technical Operations Specialist',
#   'company': 'Spotify',
#   'location': 'New York, NY•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=52a84ca3f2fc886c'},
#  {'title': 'Corporate Operations Engineer, Support, Research and Develop...',
#   'company': 'Google',
#   'location': 'New York, NY (Chelsea area)',
#   'link': 'https://www.indeed.com/viewjob?jk=56e94168f1328972'},
#  {'title': 'Research Assistant',
#   'company': 'Columbia University',
#   'location': 'New York, NY+2 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=a59d83d3f61b849f'},
#  {'title': 'Frontend Engineer, University Graduate - 2022 Start',
#   'company': 'TikTok',
#   'location': 'Seattle, WA+5 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=7423e56c5d5a069d'},
#  {'title': 'CAE Engineer Vehicle Model',
#   'company': 'Rivian Automotive',
#   'location': 'Irvine, CA+1 location',
#   'link': 'https://www.indeed.com/viewjob?jk=4387bc6f29115923'},
#  {'title': 'Front-End Visual Developer (Remote) ID: PFM21',
#   'company': 'Power Fusion Media',
#   'location': 'Las Vegas, NV 89120•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=49c61c1751450e8f'},
#  {'title': 'Platforms Solutions Consultant, gCare',
#   'company': 'Google',
#   'location': 'New York, NY (Chelsea area)',
#   'link': 'https://www.indeed.com/viewjob?jk=91c523abc4708ce5'},
#  {'title': 'ETL Development Manager',
#   'company': 'Institute for Medical Research',
#   'location': 'Durham, NC 27705 (Duke West Campus area)',
#   'link': 'https://www.indeed.com/viewjob?jk=1b6e98bc63796dac'},
#  {'title': 'GIS Technician I',
#   'company': 'Butler County, KS',
#   'location': 'El Dorado, KS',
#   'link': 'https://www.indeed.com/viewjob?jk=d0b08fe3f87d1940'},
#  {'title': 'Data Analyst',
#   'company': 'Vanguard',
#   'location': 'Charlotte, NC+3 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=8fa0cdb1b31842d9'},
#  {'title': 'Full Stack Python Engineer',
#   'company': 'Recurrent Ventures',
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=2476fc76fb73b40f'},
#  {'title': 'Data Scientist',
#   'company': 'Millennium Management LLC',
#   'location': 'New York, NY+2 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=c0caf00379d37736'},
#  {'title': 'Data Scientist',
#   'company': 'Medidata Solutions',
#   'location': 'New York, NY 10014 (West Village area)+2 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=903e94b62fd7b359'},
#  {'title': 'Quality Assurance Tester/Technician',
#   'company': 'Dolby',
#   'location': 'Colorado•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=4aa7b25244e8c9e7'},
#  {'title': 'University Grad Software Engineer (USA)',
#   'company': 'Pinterest',
#   'location': 'Seattle, WA 98101 (Denny Triangle area)+6 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=4b7d149a76d895ec'},
#  {'title': 'Risk Analyst',
#   'company': 'TikTok',
#   'location': 'Austin, TX 78745+1 location',
#   'link': 'https://www.indeed.com/viewjob?jk=9c1bbd012d8d85cc'},
#  {'title': 'Python Developer',
#   'company': 'Moove-it',
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=30d2deae65d78d38'},
#  {'title': 'Part-Time Instructor: Python Programming (Online)',
#   'company': 'The Regents of the University of California',
#   'location': 'Irvine, CA+1 location•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=d77aabb290404136'},
#  {'title': 'Data Analyst',
#   'company': 'Vroom',
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=d0401b256ecf7700'},
#  {'title': '2022 Advancing Hispanics and Latinos Fellowship Program - So...',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Columbus, OH+110 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=8107090626c1523f'},
#  {'title': 'Jr. Developer',
#   'company': 'Deloitte',
#   'location': 'Newton, MA+68 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=5331201ddf9df986'},
#  {'title': 'Junior Full Stack Engineer',
#   'company': 'InnovaSystems International, LLC',
#   'location': 'San Diego, CA 92108 (Mission Valley East area)+2 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=2b2cd03c5b901051'},
#  {'title': 'People Analyst, Strategy, Planning, and Analysis, Recruiting',
#   'company': 'Google',
#   'location': 'Los Angeles, CA (Venice area)',
#   'link': 'https://www.indeed.com/viewjob?jk=141215069508b0f3'},
#  {'title': 'Intelligence Investigator, Violent Extremism and Criminal Or...',
#   'company': 'Google',
#   'location': 'New York, NY (Chelsea area)',
#   'link': 'https://www.indeed.com/viewjob?jk=a22b52542a7a7b90'},
#  {'title': 'Data Analyst (Remote)',
#   'company': 'Montaro',
#   'location': 'San Francisco, CA•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=fba63e6037ca8c67'},
#  {'title': 'Data Scientist',
#   'company': 'Cognizant Technology Solutions',
#   'location': 'Saint Paul, MN+5 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=216e602bcf1bbbc9'},
#  {'title': 'Python Curriculum Developer',
#   'company': 'The Flatiron School',
#   'location': 'New York State•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=7fa4d865ba4d418a'},
#  {'title': 'Data Scientist, Marketing Analytics',
#   'company': 'Tinder',
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=8041a91ec93554bc'},
#  {'title': 'Software Engineer - Channel Moderation',
#   'company': 'Twitch Interactive, Inc.',
#   'location': 'San Francisco, CA+126 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=6b690ee47c07d972'},
#  {'title': 'Business Intelligence Analyst / Data Analyst',
#   'company': 'University Federal Credit Union',
#   'location': 'Salt Lake City, UT 84106 (Sugar House area)',
#   'link': 'https://www.indeed.com/viewjob?jk=4a007db9de069995'},
#  {'title': 'Full Stack Developer',
#   'company': 'Optimal Technologies',
#   'location': 'Lawrenceville, GA 30044',
#   'link': 'https://www.indeed.com/viewjob?jk=bc601784d57a6718'},
#  {'title': 'Data Scientist',
#   'company': 'Amazon Web Services, Inc.',
#   'location': 'Seattle, WA+126 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=7af3ba407830f128'},
#  {'title': 'Software Engineering: Full Time Opportunities Microsoft Leap',
#   'company': 'Microsoft',
#   'location': 'Redmond, WA 98052 (Overlake area)+21 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=b30dc784a89335c8'},
#  {'title': 'Data Center Technician',
#   'company': 'Google',
#   'location': 'Bridgeport, AL 35740',
#   'link': 'https://www.indeed.com/viewjob?jk=33f331753b3ed80a'},
#  {'title': 'Junior Front End / Full Stack Software Engineer',
#   'company': 'Plectica',
#   'location': 'New York, NY+1 location•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=168a00aa137f6f7f'},
#  {'title': 'Entry Level Engineer - Center for Spinal Stimulation',
#   'company': 'Kessler Foundation',
#   'location': 'West Orange, NJ 07052',
#   'link': 'https://www.indeed.com/viewjob?jk=e09328d444e98486'},
#  {'title': 'Sr. Systems Engineer',
#   'company': "Aaron's",
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=a5f9ae893deba38c'},
#  {'title': 'Product Development Engineer',
#   'company': 'Intel',
#   'location': 'Phoenix, AZ 85018 (Camelback East area)+19 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=002c280c00b13f22'},
#  {'title': 'Research Engineer',
#   'company': 'Optiver',
#   'location': 'Austin, TX',
#   'link': 'https://www.indeed.com/viewjob?jk=adcd5b2860b6d49d'},
#  {'title': 'Biostatistician - Health Equity Research - Full Time',
#   'company': 'Ochsner Health System',
#   'location': 'New Orleans, LA',
#   'link': 'https://www.indeed.com/viewjob?jk=8bee9ea584bd884b'},
#  {'title': 'Jr. Technologist, Content Protection',
#   'company': 'Universal Music Group',
#   'location': 'New York, NY 10107 (Midtown area)',
#   'link': 'https://www.indeed.com/viewjob?jk=c70c4f1bbbb4aefa'},
#  {'title': 'Data Visualization Engineer (Remote)',
#   'company': 'pulseData',
#   'location': 'New York, NY•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=3942093fd1bd16d3'},
#  {'title': 'Web Engineer',
#   'company': 'Airship',
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=df6ccc4b8fbe8e8b'},
#  {'title': 'Fellow, Baseball Research & Development',
#   'company': 'Cleveland Guardians - Baseball Operations',
#   'location': 'Ohio•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=175dd953bc5a4622'},
#  {'title': 'MARKETING ANALYST',
#   'company': 'DraftKings',
#   'location': 'Boston, MA',
#   'link': 'https://www.indeed.com/viewjob?jk=1853cd4b3f6f1a14'},
#  {'title': 'Network Engineer (Starlink)',
#   'company': 'SpaceX',
#   'location': 'Seattle, WA 98121 (Belltown area)+2 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=c54778ef77933769'},
#  {'title': 'AI/ML',
#   'company': 'Apple',
#   'location': 'Seattle, WA+2 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=c65906b1e69fe513'},
#  {'title': 'Data Scientist, Fraud, Talk',
#   'company': 'Spotify',
#   'location': 'New York, NY+4 locations•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=e2dbf4e6c2e243a7'},
#  {'title': 'GIS Technician',
#   'company': 'Flo Analytics',
#   'location': 'Seattle, WA+1 location',
#   'link': 'https://www.indeed.com/viewjob?jk=b5e9951b5f0dfff4'},
#  {'title': 'Python Developer',
#   'company': 'Haneke Design',
#   'location': 'Tampa, FL',
#   'link': 'https://www.indeed.com/viewjob?jk=542b21736b6bca61'},
#  {'title': 'Software Developer',
#   'company': 'IBM',
#   'location': 'Houston, TX 77001+27 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=4343554e5cad7c80'},
#  {'title': 'Quantitative Marketing Scientist, Marketing Automation, Ads',
#   'company': 'Google',
#   'location': 'New York, NY (Chelsea area)+1 location',
#   'link': 'https://www.indeed.com/viewjob?jk=b391686160c72183'},
#  {'title': 'Software Engineer (Front End)',
#   'company': "O'Reilly Media",
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=6781a6a0bf72268b'},
#  {'title': 'Mental Health & Well-being Computational Scientist',
#   'company': 'Apple',
#   'location': 'Cupertino, CA',
#   'link': 'https://www.indeed.com/viewjob?jk=60f24c4f9c0808f1'},
#  {'title': '3D Modeler - Hard Surface - Permanent Remote',
#   'company': 'Webstaurant Store, Inc.',
#   'location': 'Lititz, PA 17543•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=f1d95ac60afce9fa'},
#  {'title': 'Software Engineer I/II',
#   'company': 'Microsoft',
#   'location': 'Mountain View, CA 94043+71 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=061af954aa045263'},
#  {'title': 'Biomechanist',
#   'company': 'The Seattle Mariners Baseball Club',
#   'location': 'Peoria, AZ',
#   'link': 'https://www.indeed.com/viewjob?jk=93d816b75fca3e14'},
#  {'title': 'Software Engineer',
#   'company': 'Wolfram',
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=ef7b5a6fbb9f1f3e'},
#  {'title': 'Data Analyst - Tiktok Ads',
#   'company': 'TikTok',
#   'location': 'Seattle, WA+13 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=ea2bf81d89f746f0'},
#  {'title': 'Senior Network Engineer',
#   'company': 'Netflix',
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=32aea7792b30a709'},
#  {'title': 'Software Engineer',
#   'company': 'PayPal',
#   'location': 'Boise, ID 83701 (West Valley area)+68 locations•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=b13f62664d7a53d7'},
#  {'title': 'Front-End Developer-REMOTE',
#   'company': 'John Deere',
#   'location': 'Urbandale, IA 50322•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=a1180d6b980e554f'},
#  {'title': 'CAE Engineer - Drive Systems',
#   'company': 'Tesla',
#   'location': 'Palo Alto, CA+1 location',
#   'link': 'https://www.indeed.com/viewjob?jk=58621183f2ef4e83'},
#  {'title': 'Python Developer',
#   'company': 'Saraca Solutions',
#   'location': 'Harrisburg, PA',
#   'link': 'https://www.indeed.com/viewjob?jk=7a7f0d6cdbec9856'},
#  {'title': 'Computer Scientist',
#   'company': 'US National Institute of Standards and Technology',
#   'location': 'Gaithersburg, MD 20899•Temporarily Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=7af1f93b6b1d4000'},
#  {'title': 'Software Engineer, University Grad',
#   'company': 'Facebook App',
#   'location': '+124 locationsRemote',
#   'link': 'https://www.indeed.com/viewjob?jk=bde0b491d0d673f8'},
#  {'title': 'Thermal Systems Aerodynamicist',
#   'company': 'Tesla',
#   'location': 'Austin, TX+1 location',
#   'link': 'https://www.indeed.com/viewjob?jk=bc69499e2c02ff43'},
#  {'title': 'Threat Analyst, Minor Safety',
#   'company': 'TikTok',
#   'location': 'Mountain View, CA 94041 (Old Mountain View area)',
#   'link': 'https://www.indeed.com/viewjob?jk=4797d1bb3100fefa'},
#  {'title': 'Student Success Coordinator - DigitalCrafts',
#   'company': 'American Intercontinental University',
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=d576f0487286e965'},
#  {'title': 'CAE Engineer - Drive Systems',
#   'company': 'Tesla',
#   'location': 'Palo Alto, CA+1 location',
#   'link': 'https://www.indeed.com/viewjob?jk=58621183f2ef4e83'},
#  {'title': 'Python Developer',
#   'company': 'Deloitte',
#   'location': 'New York, NY+126 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=5ee35e78ac030932'},
#  {'title': 'Radio Hardware — Associate Engineer (Spring/Summer 2022)',
#   'company': 'Astranis',
#   'location': 'San Francisco, CA',
#   'link': 'https://www.indeed.com/viewjob?jk=e75569e6b749dfef'},
#  {'title': 'Python Dev / Analyst',
#   'company': 'Fuego Leads',
#   'location': 'Columbus, OH 43215 (Downtown area)•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=71da39d9833d51ad'},
#  {'title': 'Middle Python Developer',
#   'company': 'AgileEngine',
#   'location': 'Grow, TX',
#   'link': 'https://www.indeed.com/viewjob?jk=cd3fbcf2d291ea7d'},
#  {'title': 'Performance Analyst',
#   'company': 'NVIDIA',
#   'location': 'St. Louis, MO',
#   'link': 'https://www.indeed.com/viewjob?jk=e87b422c60a5df11'},
#  {'title': 'Python Developer',
#   'company': 'Nuvento systems',
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=f2beba2d5640fd15'},
#  {'title': 'CAE Engineer Vehicle Model',
#   'company': 'Rivian Automotive',
#   'location': 'Irvine, CA+1 location',
#   'link': 'https://www.indeed.com/viewjob?jk=4387bc6f29115923'},
#  {'title': 'Escalation Engineer (HEM)',
#   'company': 'Amazon Web Services, Inc.',
#   'location': 'West Valley City, UT 84120+7 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=51f0cb3830a3dc98'},
#  {'title': 'Marketing Data Scientist (Remote)',
#   'company': 'Shipt',
#   'location': 'Birmingham, AL 35203 (Central City area)+6 locations•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=1c0e4c5b17e2b7ed'},
#  {'title': 'Product Analyst',
#   'company': 'Swing Education',
#   'location': 'San Mateo, CA 94402 (B-Delaware Strip area)•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=29e37f3f5b431994'},
#  {'title': 'Python Engineer (remote)',
#   'company': 'magnitude',
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=0579faf2b17d7b9d'},
#  {'title': 'Robotics Team Coach',
#   'company': 'The Bush School',
#   'location': 'Seattle, WA 98112 (Madison Valley area)',
#   'link': 'https://www.indeed.com/viewjob?jk=4a7a741fb0916769'},
#  {'title': 'Research Assistant I - Systems Neurobiology Laboratory',
#   'company': 'Salk Institute for Biological Studies',
#   'location': 'La Jolla, CA 92037',
#   'link': 'https://www.indeed.com/viewjob?jk=db0038d0b797a58d'},
#  {'title': 'Test Engineer',
#   'company': 'ArthurPaige',
#   'location': 'Fort Meade, MD',
#   'link': 'https://www.indeed.com/viewjob?jk=a06ce18d89a2f848'},
#  {'title': 'Python Developer',
#   'company': 'CSC Generation',
#   'location': 'United States+1 location•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=18af2dad2032cf22'},
#  {'title': 'Python Engineer - Banking Platform Team',
#   'company': 'Avant',
#   'location': '+1 locationRemote',
#   'link': 'https://www.indeed.com/viewjob?jk=7f97b256c3c7e391'},
#  {'title': 'Research Analyst',
#   'company': 'Voloridge Investment Management',
#   'location': 'Jupiter, FL+1 location',
#   'link': 'https://www.indeed.com/viewjob?jk=618af6ae73e4049d'},
#  {'title': 'Data Specialist',
#   'company': 'YipitData',
#   'location': 'New York State+1 location•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=99aaf2d66679bf6a'},
#  {'title': 'Quantitative Marketing Research Analyst, Brand Studio',
#   'company': 'Google',
#   'location': 'New York, NY (Chelsea area)+2 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=a92abecfd8389884'},
#  {'title': 'Data Engineer',
#   'company': 'Tesla',
#   'location': '+8 locationsRemote',
#   'link': 'https://www.indeed.com/viewjob?jk=c88b779349d52e66'},
#  {'title': 'Entry Level Back End Developer: 2022',
#   'company': 'IBM',
#   'location': 'Research Triangle Park, NC 27709+10 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=86a4e46879c3a823'},
#  {'title': 'Marketing Analyst',
#   'company': 'Adobe',
#   'location': 'Lehi, UT 84043',
#   'link': 'https://www.indeed.com/viewjob?jk=ca3f6248bf2f1298'},
#  {'title': 'Analyst- Airlines Practice',
#   'company': 'Compass Lexecon',
#   'location': 'Boston, MA 02109 (Haymarket area)',
#   'link': 'https://www.indeed.com/viewjob?jk=880fe00c5f3577ff'},
#  {'title': 'Research Analyst',
#   'company': 'State of Hawaii Department of the Attorney General',
#   'location': 'Honolulu, HI 96813 (Downtown area)+1 location',
#   'link': 'https://www.indeed.com/viewjob?jk=27cb681a75910b84'},
#  {'title': 'Junior Software Engineer',
#   'company': 'SPECTRIO LLC',
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=320e0ca0515f2896'},
#  {'title': 'Data Engineer (Python, Pyspark, Airflow, AWS)',
#   'company': 'Nexient',
#   'location': 'United States+2 locations•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=5bab58e365fc1417'},
#  {'title': 'Robotics Research Engineer',
#   'company': 'Vicarious',
#   'location': 'Union City, CA 94587+5 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=63f1ab1789a1fe35'},
#  {'title': 'Software Engineer I/II',
#   'company': 'Microsoft',
#   'location': 'Mountain View, CA 94043+71 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=061af954aa045263'},
#  {'title': 'Python Developer',
#   'company': 'Swan Software Solutions',
#   'location': 'Carmel, IN',
#   'link': 'https://www.indeed.com/viewjob?jk=32eaa9e1e80e8c5d'},
#  {'title': 'AI/ML Residency Program',
#   'company': 'Apple',
#   'location': 'Cambridge, MA+2 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=7f890510f97466e2'},
#  {'title': 'Research Analyst - 2022',
#   'company': 'MarketAxess',
#   'location': 'New York, NY 10001 (Chelsea area)',
#   'link': 'https://www.indeed.com/viewjob?jk=5b3662c83c0fe73c'},
#  {'title': 'Flight Test Specialist',
#   'company': 'Wing',
#   'location': 'California•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=d70445a0368de1e1'},
#  {'title': 'Data Consultant',
#   'company': 'Yipit Inc.',
#   'location': 'New York, NY+3 locations•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=c440b43f18a16bc9'},
#  {'title': 'CGD/Oceanography Associate Scientist I/II',
#   'company': 'University Corporation for Atmospheric Research',
#   'location': 'Boulder, CO+1 location',
#   'link': 'https://www.indeed.com/viewjob?jk=55a49ef50460b9f9'},
#  {'title': 'Software Engineer',
#   'company': 'Tomorrow Health',
#   'location': 'New York, NY',
#   'link': 'https://www.indeed.com/viewjob?jk=7561254d545e276a'},
#  {'title': 'Associate, YouTube',
#   'company': 'YouTube',
#   'location': 'New York, NY',
#   'link': 'https://www.indeed.com/viewjob?jk=a19d5d6e71bffeee'},
#  {'title': 'Junior Web Developer',
#   'company': 'HealPay',
#   'location': 'Ann Arbor, MI+1 location',
#   'link': 'https://www.indeed.com/viewjob?jk=84e78087102e5db1'},
#  {'title': 'Cyber Crime Analyst',
#   'company': 'Barclays',
#   'location': 'Florida•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=8b2e175c0cf2cdba'},
#  {'title': 'Associate Online Engineer - Raven Software',
#   'company': 'Raven Software',
#   'location': 'Middleton, WI 53562',
#   'link': 'https://www.indeed.com/viewjob?jk=136fffced9dad90d'},
#  {'title': 'Software Engineer Apprentice',
#   'company': 'IBM',
#   'location': 'Rochester, MN 55901+27 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=a3693dd23cfafae6'},
#  {'title': 'Data Technician (Full- or Part-Time)',
#   'company': 'Thasos Group',
#   'location': 'New York, NY',
#   'link': 'https://www.indeed.com/viewjob?jk=da727c0cddda240e'},
#  {'title': 'Quantitative Trader - Entry Level',
#   'company': 'Avatar Securities',
#   'location': 'Chicago, IL',
#   'link': 'https://www.indeed.com/viewjob?jk=d01efa8dad29efdc'},
#  {'title': 'Software Engineer',
#   'company': 'Leading2Lean (L2L)',
#   'location': 'Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=261ddd6bfc708e27'},
#  {'title': 'Software Engineer I',
#   'company': 'Disney Media & Entertainment Distribution',
#   'location': 'Seattle, WA+3 locations',
#   'link': 'https://www.indeed.com/viewjob?jk=d9ff90d6845f27de'},
#  {'title': 'Associate, Audits - Health Data Informatics - June 2022 - Re...',
#   'company': 'The Segal Group, Inc.',
#   'location': 'New York, NY•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=db399a848bc9aa4d'},
#  {'title': 'Predictive Model Analyst - Binghamton University',
#   'company': 'Binghamton University',
#   'location': 'Binghamton, NY 13902',
#   'link': 'https://www.indeed.com/viewjob?jk=eec2f6d24e3cd0e6'},
#  {'title': 'Python Developer',
#   'company': 'Snap IT Solutions',
#   'location': 'Houston, TX 77099 (Alief area)',
#   'link': 'https://www.indeed.com/viewjob?jk=0e10fe734c597c75'},
#  {'title': 'PhD Residency - Supply Chain - Agent-Based Modeling',
#   'company': 'Loon',
#   'location': 'Mountain View, CA',
#   'link': 'https://www.indeed.com/viewjob?jk=f877a6cd9b93bc8e'},
#  {'title': 'Data Scientist',
#   'company': 'Alldus',
#   'location': 'New York, NY+3 locations•Remote',
#   'link': 'https://www.indeed.com/viewjob?jk=adb76a663717691a'}]
